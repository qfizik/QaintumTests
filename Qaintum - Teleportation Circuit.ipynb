# %%
using Qaintessent
using LinearAlgebra
using Random

# %%
#Creates a random N-qubit state

function RandomState(N)
    ψ = randn(ComplexF64, 2*N)
    ψ /= norm(ψ)
    return(ψ)
end
# Out:
# RandomState (generic function with 1 method)

# %%
#We are trying to teleport from wire 1 to wire 3
#Wire 1 is the fastest varying 

teleport_circuit = CircuitGate[
        circuit_gate(2, HadamardGate()),   
        circuit_gate(3, XGate(), 2),
        circuit_gate(2, XGate(), 1),
        circuit_gate(1, HadamardGate()),
        circuit_gate(3,XGate(),2),
        circuit_gate(3, ZGate(),1)
        ]
    
    meas = [
    MeasurementOperator(X, (1,)),
    MeasurementOperator(X, (2,)) ]
                                                  #and use them as control for Bob's X,Z gates

    c = Circuit{3}(teleport_circuit, meas)
    println(c)
# Out:
#     3 ———————[X ]————————[X ]——[Z ]—
#               |           |     |
#     2 —[H ]———•————[X ]———•—————————
#                     |           |
#     1 ——————————————•————[H ]———•———

# %%
#Let's create a random single-qubit state to be teleported
#As we are teleporting from 1 to 3 the tensor product should have the teleporting state as 1st term
                 
for i=1:100
    ψ = RandomState(1)
    println("The state to be teleported is", ψ)
    ϕ = kron(ComplexF64[1,0],[1,0])
    ψ_total_initial = kron(ϕ, ψ)
    println(apply(c, ψ_total_initial))
end
# Out:
# The state to be teleported isComplex{Float64}[0.4769884702395081 - 0.6748152572183705im, -0.5184874873421638 + 0.21972048915266856im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.35550819281644735 - 0.4503729827173144im, -0.37478578360083475 + 0.7282264192470647im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.5686159723021044 + 0.2819465156992735im, -0.6929521066896286 + 0.3420517740962286im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.0645433977919413 - 0.5640137414748609im, -0.5428220037901835 + 0.6189240029520667im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.7272929584875559 - 0.5534158205248337im, -0.10724323914384394 - 0.39150321810322275im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[0.602193547106928 + 0.5990278597871876im, 0.4237687212158246 + 0.3145610051177078im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[0.6444429634192451 - 0.36059370930049434im, -0.19333842143522473 - 0.6459765464080468im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.5294855897305052 - 0.28587569736357044im, -0.0852535066862688 - 0.7941359679062054im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.20471996494314115 + 0.7699024208244645im, -0.22171825254073083 - 0.5622997553374827im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.24068739139133305 - 0.23106242741560384im, -0.7445062600201177 + 0.5782647862812512im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[0.5197898110525646 - 0.2488647453205901im, -0.6942186235790213 - 0.4312138605593589im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[0.44139628492880817 - 0.6562344326606055im, -0.6045927510968166 - 0.09483298140859177im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.5569858540114901 - 0.6148974861383909im, 0.12234764769415821 + 0.5447007371717838im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[0.5236848457522096 - 0.025262250945392032im, -0.1939630646915466 - 0.8291527787700644im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.831078436534995 + 0.060642675930631655im, -0.5289460686502954 + 0.16077050302190907im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.6859941049595799 - 0.3776469036263823im, 0.5247316088810605 - 0.33384374006891965im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.22584487358642133 + 0.03244316063008458im, 0.9710345214985194 - 0.07094711030905577im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.8668810229231042 - 0.3304667884599879im, -0.33540160657148627 - 0.16375211794050232im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.10689486725590089 - 0.03622007350625974im, -0.9029806963701474 - 0.41459312055607966im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.0694599642799044 + 0.9538713110100426im, 0.23507301023500762 + 0.17333642217742032im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.36927632928105925 - 0.7193977806253178im, 0.5225928717006781 + 0.2701823760198142im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.5031053395912436 - 0.7368109224059993im, -0.3733141147281779 - 0.2542267760144799im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.4802605552813563 + 0.8004787121574674im, 0.014314900235707362 - 0.35829975447215673im]
# [1.0000000000000002, 1.0000000000000002]
# The state to be teleported isComplex{Float64}[-0.5920209906510391 - 0.5322961283699758im, 0.5969724182887437 - 0.0989742903656593im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.0765983528058503 - 0.03171257185174702im, 0.9905628124238249 + 0.109143574144246im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.1494377948707696 + 0.394478439764948im, -0.9039562732151992 - 0.07012960957870931im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.5983368355351503 + 0.3946753505755346im, -0.6197412723572999 - 0.31960155541989543im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.035493613120863195 - 0.46490205512780247im, -0.10781327037405715 - 0.8780561378959906im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.3306796995044252 + 0.569107929632659im, 0.6440119488360707 - 0.38989192159014746im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.1727771126992576 + 0.22444353858607932im, -0.7004493368768385 + 0.6550907523260148im]
# [0.9999999999999993, 0.9999999999999993]
# The state to be teleported isComplex{Float64}[-0.22292290160379408 + 0.6075215126300649im, -0.7623795630528896 + 0.0006272730731156431im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[-0.22252979067489215 + 0.06941637218625153im, -0.9300845047845068 - 0.28390962205329917im]
# [0.9999999999999994, 0.9999999999999994]
# The state to be teleported isComplex{Float64}[-0.06948613333731923 + 0.902509509830682im, 0.22273003758744314 - 0.3619939119588982im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.3550913422777282 + 0.002174696629826237im, -0.7943554963947796 + 0.4928536848613114im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.5561569257739956 - 0.09764367315675665im, -0.33636973594976965 + 0.7536647714621914im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[0.19760776071574546 - 0.534163313288175im, 0.2878624162545733 + 0.7699064598702796im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.33560684974947386 - 0.4081751045032869im, -0.6932138854662525 + 0.49011798116550065im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.6009186449627507 - 0.4637992754211961im, -0.4236131733833068 - 0.4943064773913342im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.6793053130281603 - 0.6553882199698148im, -0.14912230994843334 + 0.29457275755261925im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.3652021969097838 - 0.053173263185899135im, -0.9035643480596969 - 0.21764978375795746im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.958932122961793 - 0.04653542256333513im, -0.2763978092446654 - 0.04344984515035674im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.7437152098920583 + 0.6207616143168531im, 0.05705587841144393 + 0.24142769415426343im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.4346113971111482 + 0.09448053017447933im, -0.8041537993789148 - 0.3943640828771064im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.01679134145383148 - 0.5807872293134327im, 0.06724792324364316 - 0.811099230635823im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[-0.5622891513971187 + 0.4892482735398077im, 0.6034106060280461 + 0.28348311694401107im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.6502995288146896 - 0.42943400665262776im, -0.3562409362683611 + 0.5155476234842955im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.7783541988923582 - 0.39444144680357857im, 0.3989078767035825 - 0.2818744259665542im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.11323144175752586 + 0.27237890391034214im, -0.9378393132204531 - 0.18288191786041014im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.20013690204258025 + 0.1824365984422892im, 0.7884104020925905 + 0.5523324595402711im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.21580776828165088 - 0.7178378936147544im, -0.5161193036197969 + 0.41443531470066824im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[0.218804200085682 + 0.5305356081445317im, -0.4141087237095056 - 0.7065201026603993im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[-0.8849276554878144 - 0.12491909219658143im, -0.2545924532690548 + 0.3694332790857728im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.5102754163162697 + 0.23770173116016963im, 0.811735380594072 + 0.15557171464798172im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.4125067377904346 - 0.3523732233674069im, -0.04138404361812619 + 0.8390224452688797im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.4076978902340931 - 0.8816393019834653im, 0.23650674027836402 - 0.02364599965490628im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.4774815862697151 + 0.7235279861897311im, -0.4367892590647012 - 0.24027844501598167im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.5402568802977873 - 0.014835860834920845im, -0.6553815573161471 - 0.5276148357031396im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.32340939366990107 + 0.0559177436558103im, 0.9337178211312214 - 0.14300559615789335im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.14687595023616642 + 0.005466402609535704im, 0.20299815085740108 + 0.9680853910855227im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.3192725987488036 - 0.1872140898873354im, 0.7120067049625973 + 0.5967095979822572im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.8813768918315258 - 0.13909599319447655im, 0.4350638143818462 - 0.12060910677954483im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.8906283213810461 + 0.3517688766097172im, 0.27862290579172205 + 0.0735467672361931im]
# [0.9999999999999994, 0.9999999999999994]
# The state to be teleported isComplex{Float64}[0.3773030323554579 - 0.6162921304074437im, 0.16447048779069393 - 0.6713984587553966im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.7532910082729308 + 0.6348090390159634im, -0.17190247115592905 + 0.00443635540336174im]
# [0.9999999999999993, 0.9999999999999993]
# The state to be teleported isComplex{Float64}[-0.6679153509998024 + 0.05587485097555193im, 0.005397747761042244 + 0.7421172072162044im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.09178680927616611 - 0.7879065287041395im, 0.5813755679961297 + 0.18105505407326114im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.3575439902787401 + 0.766011164847187im, -0.5130469783586646 + 0.14890261361727625im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.6805067961112796 - 0.5507140556789577im, -0.4018680454326571 - 0.26856396516310793im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.1550785848153814 - 0.5982675457682844im, -0.10709554205843438 - 0.7788177714223414im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.12562019766691002 + 0.01846042960862705im, -0.9752319881080547 - 0.1811114238462128im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.337210279220418 - 0.6004373769692875im, 0.15638903633465506 - 0.7080301217043296im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[0.26435594191180034 + 0.11509135081861359im, -0.5765840055527767 + 0.7644741993575633im]
# [1.0, 1.0]
# The state to be teleported isComplex{Float64}[-0.25871309870540415 + 0.3485344456770956im, 0.8535762139480062 - 0.2880953309531325im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.728642245760127 - 0.4749484256661753im, -0.49274265504225484 - 0.02662980572158685im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.3879489627782325 - 0.6414530040244592im, 0.6439660313610606 + 0.15277891333681004im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.7112847311774557 + 0.2673676343691975im, 0.244770431968082 - 0.6022258836348635im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.8048377403725643 - 0.07491208772188564im, -0.5073852501924669 - 0.2986379056185955im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.3692110435127059 - 0.6766274683952005im, -0.14247047056773995 - 0.6209352940343845im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.08062501916065717 + 0.8147723277069187im, -0.0909440920180094 - 0.566899314177935im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.039872462909620016 + 0.47544769386628793im, 0.7468051246023519 - 0.46329448838337695im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.48496933439975815 - 0.5312204531280655im, -0.20593594728045245 + 0.6634756668393882im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.2965174622505981 + 0.6922056107627068im, 0.4786744700287252 - 0.4514416227507297im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.6169443767874783 + 0.046856498589292785im, -0.5022341604842824 - 0.60410673935399im]
# [0.9999999999999994, 0.9999999999999994]
# The state to be teleported isComplex{Float64}[0.3286622592033961 - 0.44207088930571536im, 0.6381672902040947 + 0.5378633264290625im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[-0.21039028352352868 + 0.35785346995149525im, 0.6634258826774599 + 0.622529453790097im]
# [0.9999999999999996, 0.9999999999999996]
# The state to be teleported isComplex{Float64}[0.7292311763802627 - 0.5864862824798579im, 0.3235632892865105 - 0.1398661134231898im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.07420619921794941 - 0.9139124887241525im, 0.008247239967874418 + 0.39898544583050133im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.2746751044117569 + 0.33805216930664406im, 0.06548728166831108 - 0.8977670821450058im]
# [0.9999999999999993, 0.9999999999999993]
# The state to be teleported isComplex{Float64}[0.187847168910114 + 0.4513024892417092im, 0.08497182190525264 + 0.8682276739535514im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[-0.05541926672030275 - 0.39107935847473657im, -0.9161187446643799 + 0.06864463508339921im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.9861520557875187 + 0.15938415761281263im, 0.02521739001165252 - 0.03827396516047119im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[0.7363578408054241 - 0.5100796218905278im, 0.3857247975862325 - 0.22093503602518522im]
# [0.9999999999999999, 0.9999999999999999]
# The state to be teleported isComplex{Float64}[0.5410675460442579 + 0.07452313054766985im, -0.5295163321583588 - 0.6490798622731863im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.039821443442602474 - 0.7632987018391795im, -0.1906102646469178 - 0.6160008696617261im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[0.2481359061876119 + 0.3742238645086064im, -0.13882106319199566 - 0.8826742228630793im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.2936508434718761 - 0.08348007022384361im, -0.8365152083920322 + 0.45501930303286353im]
# [0.9999999999999997, 0.9999999999999997]
# The state to be teleported isComplex{Float64}[-0.28166853432937483 + 0.39378037928885934im, -0.8515404852085507 + 0.2011930707222542im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[-0.5388624449113235 - 0.18222247768457595im, 0.8150576558471504 - 0.11001477962361872im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.40474244840074075 + 0.6624346363245688im, -0.54939653535859 + 0.30907499089393764im]
# [0.9999999999999998, 0.9999999999999998]
# The state to be teleported isComplex{Float64}[0.1506237794163468 + 0.31396716035124705im, -0.6726017175028453 + 0.6529502499482888im]
# [0.9999999999999998, 0.9999999999999998]
