# %%
using Qaintessent
using LinearAlgebra
using Random

# %%
bell00_circuit = CircuitGate[
        circuit_gate(2, HadamardGate()),   
        #circuit_gate(1, XGate(), 2),
        circuit_gate(1,2, ControlledGate(X,1))
        
    ]
        
           
meas = [MeasurementOperator(X, (1)),
        MeasurementOperator(X, (2))]
    
c = Circuit{2}(bell00_circuit, meas)
    println(c)
# Out:
#     2 —[H ]———•———
#               |
#     1 ———————[X ]—

# %%
for i=1:100
    ϕi = kron(ComplexF64[1,0],[1,0])
    println(ϕi)
    println(apply(c, ϕi))
end
# Out:
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# [0.0, 0.0]
# Complex{Float64}[1.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im]
# ...
